# %% [markdown]
# # Pattern: Two Pointers
#
# ## When to use it
# - Array or string is **sorted** (or you can sort it)
# - You're looking for a **pair** or need to compare elements from both ends
# - Problem asks you to do it in O(1) space
#
# ## The pattern
# ```
# left = 0
# right = len(arr) - 1
#
# while left < right:
#     if condition met:
#         return result
#     elif need bigger value:
#         left += 1
#     else:
#         right -= 1
# ```
#
# ## Variants
# 1. **Opposite ends** — left starts at 0, right at end, move toward each other
# 2. **Same direction** — both start at 0, one is read pointer, one is write pointer (like Remove Duplicates)
# 3. **Different arrays** — one pointer per array, merge them

# %%
# EXAMPLE 1 — Valid Palindrome (opposite ends)
# Check if a string reads the same forwards and backwards
# Only consider alphanumeric characters, ignore case

def isPalindrome(s: str) -> bool:
    left, right = 0, len(s) - 1
    
    while left < right:
        # skip non-alphanumeric
        while left < right and not s[left].isalnum():
            left += 1
        while left < right and not s[right].isalnum():
            right -= 1
        
        if s[left].lower() != s[right].lower():
            return False
        left += 1
        right -= 1
    
    return True

print(isPalindrome('A man, a plan, a canal: Panama'))  # True
print(isPalindrome('race a car'))                       # False

# %%
# EXAMPLE 2 — Two Sum II (sorted array, opposite ends)
# Given sorted array, find two numbers that sum to target
# Return 1-indexed positions

from typing import List

def twoSumSorted(numbers: List[int], target: int) -> List[int]:
    left, right = 0, len(numbers) - 1
    
    while left < right:
        total = numbers[left] + numbers[right]
        if total == target:
            return [left + 1, right + 1]  # 1-indexed
        elif total < target:
            left += 1   # need bigger sum, move left forward
        else:
            right -= 1  # need smaller sum, move right back
    
    return []

print(twoSumSorted([2, 7, 11, 15], 9))   # [1, 2]
print(twoSumSorted([2, 3, 4], 6))        # [1, 3]

# %%
# EXAMPLE 3 — Remove Duplicates (same direction / read-write pointers)
# You did this at the start of today's session

def removeDuplicates(nums: List[int]) -> int:
    write = 1
    for read in range(1, len(nums)):
        if nums[read] != nums[read - 1]:
            nums[write] = nums[read]
            write += 1
    return write

nums = [1, 1, 2, 3, 3, 4]
k = removeDuplicates(nums)
print(nums[:k])  # [1, 2, 3, 4]

# %%
# EXERCISE 1 — implement from scratch
# Reverse a string in-place using two pointers
# Input: ['h','e','l','l','o']
# Output: ['o','l','l','e','h']

def reverseString(s: List[str]) -> None:
    pass

s = ['h','e','l','l','o']
reverseString(s)
assert s == ['o','l','l','e','h']
print('Reverse String: passed')

# %%
# EXERCISE 2 — 3Sum (harder, uses two pointers inside a loop)
# Find all unique triplets that sum to zero
# Input: [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]

# Approach:
# 1. Sort the array
# 2. For each element i, use two pointers on the rest
# 3. Skip duplicates

def threeSum(nums: List[int]) -> List[List[int]]:
    pass

result = threeSum([-1, 0, 1, 2, -1, -4])
print(result)  # [[-1, -1, 2], [-1, 0, 1]]

# %%
# EXERCISE 3 — Container With Most Water (LC #11)
# Given heights, find two lines that form container with most water
# Input: [1,8,6,2,5,4,8,3,7]
# Output: 49

# Hint: area = min(height[left], height[right]) * (right - left)
# Always move the pointer with the smaller height

def maxArea(height: List[int]) -> int:
    pass

assert maxArea([1,8,6,2,5,4,8,3,7]) == 49
print('Container With Most Water: passed')
