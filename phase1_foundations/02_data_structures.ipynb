# %% [markdown]
# # Data Structures
# Implement each one from scratch. Then close the notebook and rewrite it the next day.
#
# Understanding how these work under the hood makes the LeetCode problems click.

# %% [markdown]
# ## 1. Stack
# Last In First Out (LIFO). Think: a stack of plates.
# - `push` — add to top
# - `pop` — remove from top
# - `peek` — look at top without removing
#
# **Used for:** Valid Parentheses, Min Stack, Evaluate Expression, Backtracking

# %%
# EXAMPLE — fully implemented Stack
class Stack:
    def __init__(self):
        self.stack = []

    def push(self, val):
        self.stack.append(val)

    def pop(self):
        if not self.stack:
            return None
        return self.stack.pop()

    def peek(self):
        if not self.stack:
            return None
        return self.stack[-1]

    def is_empty(self):
        return not self.stack

    def __len__(self):
        return len(self.stack)

    def __str__(self):
        return 'Stack: ' + str(self.stack)

# Test it
s = Stack()
s.push(1)
s.push(2)
s.push(3)
print(s)            # Stack: [1, 2, 3]
print(s.peek())     # 3
print(s.pop())      # 3
print(s.pop())      # 2
print(len(s))       # 1

# %%
# EXERCISE — rewrite Stack from memory, no looking above
class Stack:
    def __init__(self):
        self.stack = []

    def push():
        pass

    def pop():
        pass
    
    def peek():
        pass
    
# Test — these should all pass
s = Stack()
s.push(10)
s.push(20)
s.push(30)
assert s.peek() == 30
assert s.pop() == 30
assert s.pop() == 20
assert len(s) == 1
assert s.is_empty() == False
s.pop()
assert s.is_empty() == True
assert s.pop() == None
print('Stack: all tests passed')

# %% [markdown]
# ## 2. Queue
# First In First Out (FIFO). Think: a queue at a shop.
# - `enqueue` — add to back
# - `dequeue` — remove from front
#
# **Use `collections.deque`** — appending/popping from both ends is O(1). A regular list is O(n) for pop(0).
#
# **Used for:** BFS (level order traversal), sliding window problems

# %%
# EXAMPLE
from collections import deque

class Queue:
    def __init__(self):
        self.queue = deque()

    def enqueue(self, val):
        self.queue.append(val)      # add to right

    def dequeue(self):
        if not self.queue:
            return None
        return self.queue.popleft() # remove from left

    def peek(self):
        if not self.queue:
            return None
        return self.queue[0]

    def is_empty(self):
        return not self.queue

    def __len__(self):
        return len(self.queue)

# Test it
q = Queue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
print(q.dequeue())  # 1 (first in, first out)
print(q.dequeue())  # 2
print(q.peek())     # 3

# %%
# EXERCISE — implement Queue from scratch
from collections import deque

class Queue:
    pass

# Test
q = Queue()
q.enqueue('a')
q.enqueue('b')
q.enqueue('c')
assert q.dequeue() == 'a'
assert q.peek() == 'b'
assert len(q) == 2
assert q.is_empty() == False
q.dequeue()
q.dequeue()
assert q.is_empty() == True
assert q.dequeue() == None
print('Queue: all tests passed')

# %% [markdown]
# ## 3. Linked List
# Nodes connected by pointers. Unlike arrays, memory is not contiguous.
# - Insert/delete at head: O(1)
# - Search: O(n)
# - No random access (can't do `list[3]`)
#
# **Used for:** Many LeetCode problems. Reverse Linked List, Merge Two Sorted Lists, Detect Cycle

# %%
# EXAMPLE
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, val):
        new_node = ListNode(val)
        if not self.head:
            self.head = new_node
            return
        curr = self.head
        while curr.next:        # traverse to end
            curr = curr.next
        curr.next = new_node

    def prepend(self, val):     # add to front — O(1)
        new_node = ListNode(val)
        new_node.next = self.head
        self.head = new_node

    def delete(self, val):
        if not self.head:
            return
        if self.head.val == val:
            self.head = self.head.next
            return
        curr = self.head
        while curr.next:
            if curr.next.val == val:
                curr.next = curr.next.next  # skip the node
                return
            curr = curr.next

    def to_list(self):          # helper to visualise
        result = []
        curr = self.head
        while curr:
            result.append(curr.val)
            curr = curr.next
        return result

# Test it
ll = LinkedList()
ll.append(1)
ll.append(2)
ll.append(3)
ll.prepend(0)
print(ll.to_list())  # [0, 1, 2, 3]
ll.delete(2)
print(ll.to_list())  # [0, 1, 3]

# %%
# EXERCISE — implement LinkedList from scratch
class ListNode:
    pass

class LinkedList:
    pass

# Test
ll = LinkedList()
ll.append(10)
ll.append(20)
ll.append(30)
ll.prepend(5)
assert ll.to_list() == [5, 10, 20, 30]
ll.delete(20)
assert ll.to_list() == [5, 10, 30]
ll.delete(5)
assert ll.to_list() == [10, 30]
print('LinkedList: all tests passed')

# %% [markdown]
# ## 4. Binary Tree
# Each node has at most 2 children (left and right).
#
# **Three traversal orders — know all three:**
# - Inorder: left → root → right (gives sorted order in BST)
# - Preorder: root → left → right
# - Postorder: left → right → root
#
# **Used for:** Many medium/hard problems. Max Depth, Level Order, Invert Tree, Validate BST

# %%
# EXAMPLE
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# Build a tree manually:
#       4
#      / \
#     2   6
#    / \ / \
#   1  3 5  7

root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(6)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)
root.right.left = TreeNode(5)
root.right.right = TreeNode(7)

def inorder(node):
    if not node:
        return []
    return inorder(node.left) + [node.val] + inorder(node.right)

def max_depth(node):
    if not node:
        return 0
    return 1 + max(max_depth(node.left), max_depth(node.right))

print(inorder(root))    # [1, 2, 3, 4, 5, 6, 7]
print(max_depth(root))  # 3

# %%
# EXERCISE — implement from scratch

class TreeNode:
    pass

# Build the same tree as above and implement:

# 1. inorder traversal — returns list of values
def inorder(node):
    pass

# 2. max depth
def max_depth(node):
    pass

# 3. invert the tree (mirror it left-right)
def invert_tree(node):
    pass

# Build and test
root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(6)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)
root.right.left = TreeNode(5)
root.right.right = TreeNode(7)

assert inorder(root) == [1, 2, 3, 4, 5, 6, 7]
assert max_depth(root) == 3
invert_tree(root)
assert inorder(root) == [7, 6, 5, 4, 3, 2, 1]
print('Binary Tree: all tests passed')
